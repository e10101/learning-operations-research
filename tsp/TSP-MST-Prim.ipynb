# %% [markdown]
# # MST Prim

# %% [markdown]
# ## Create Graph

# %%
import networkx as nx

# %%
n = 7
G = nx.complete_graph(n)

# %%
nx.draw(G)

# %% [markdown]
# ## Create Positions

# %%
import random

node_pos = {i: (random.random(), random.random()) for i in range(n)}
node_pos
# Out:
# {0: (0.3622715340812819, 0.5321564731027671),
#  1: (0.9043406351951543, 0.4676037596967575),
#  2: (0.27228122050655346, 0.6773288408456589),
#  3: (0.3373872628764565, 0.8551424566474071),
#  4: (0.3020025449227295, 0.9868731959146243),
#  5: (0.6184892027013559, 0.5539161950920809),
#  6: (0.018291938351003623, 0.740042432500835)}

# %%
nx.draw(G, pos=node_pos)

# %%
nx.draw(G, pos=node_pos, labels={i: i for i in range(n)})

# %% [markdown]
# ## Set Weights

# %%
import math

def distance(pos1, pos2):
    return math.sqrt((pos1[0] - pos2[0])**2 + (pos1[1] - pos2[1])**2)

# %%
distance(node_pos[0], node_pos[1])
# Out:
# 0.5458992243908027

# %%
for (n1, n2) in G.edges:
    G.edges[(n1, n2)]['distance'] = distance(node_pos[n1], node_pos[n2])

# %%
for (n1, n2) in G.edges:
    dist = G.edges[(n1, n2)]['distance']
    print(f'The distance from {n1} to {n2} is {dist}')
# Out:
# The distance from 0 to 1 is 0.5458992243908027
# The distance from 0 to 2 is 0.17080185272225637
# The distance from 0 to 3 is 0.32394316248331856
# The distance from 0 to 4 is 0.45869341510310463
# The distance from 0 to 5 is 0.25713999924974384
# The distance from 0 to 6 is 0.4019185668684899
# The distance from 1 to 2 is 0.6659457285390529
# The distance from 1 to 3 is 0.6867476741990113
# The distance from 1 to 4 is 0.7952684593161312
# The distance from 1 to 5 is 0.2985981881435794
# The distance from 1 to 6 is 0.9269871216033504
# The distance from 2 to 3 is 0.1893580701146991
# The distance from 2 to 4 is 0.31096794831640334
# The distance from 2 to 5 is 0.3675467971120069
# The distance from 2 to 6 is 0.261617182211306
# The distance from 3 to 4 is 0.1364003883152551
# The distance from 3 to 5 is 0.41201403037265505
# The distance from 3 to 6 is 0.3392194594838945
# The distance from 4 to 5 is 0.5362980226638331
# The distance from 4 to 6 is 0.37605469555469007
# The distance from 5 to 6 is 0.6283945674379964

# %%
nx.draw(G, pos=node_pos, labels={i: i for i in range(n)})

# %% [markdown]
# ## Prim Algorithm

# %%
selected_edges = []
selected_nodes = [5]

while len(selected_nodes) < len(G.nodes):
    shortest_edge = None
    shortest_weight = 100
    
    for node in selected_nodes:
        neighbors = G.neighbors(node)
    
        for neighbor in neighbors:
            if neighbor not in selected_nodes:
                dist = G.edges[(node, neighbor)]['distance']
                if dist < shortest_weight:
                    shortest_weight = dist
                    shortest_edge = (node, neighbor)
    
    selected_nodes.append(shortest_edge[1])
    selected_edges.append(shortest_edge)
    
    print(f'shortest_edge: {shortest_edge}, shortest_weight: {shortest_weight}')
# Out:
# shortest_edge: (5, 0), shortest_weight: 0.25713999924974384
# shortest_edge: (0, 2), shortest_weight: 0.17080185272225637
# shortest_edge: (2, 3), shortest_weight: 0.1893580701146991
# shortest_edge: (3, 4), shortest_weight: 0.1364003883152551
# shortest_edge: (2, 6), shortest_weight: 0.261617182211306
# shortest_edge: (5, 1), shortest_weight: 0.2985981881435794

# %%
pool_nodes
# Out:
# {0, 1, 2, 3, 4, 6}

# %%
for node in list(G.neighbors(5)):
    print(f'The distance from 5 to {node} is {G.edges[(5, node)]["distance"]}')
# Out:
# The distance from 5 to 0 is 0.25713999924974384
# The distance from 5 to 1 is 0.2985981881435794
# The distance from 5 to 2 is 0.3675467971120069
# The distance from 5 to 3 is 0.41201403037265505
# The distance from 5 to 4 is 0.5362980226638331
# The distance from 5 to 6 is 0.6283945674379964

# %% [markdown]
# ## Result

# %%
nx.draw(G, pos=node_pos, labels={i: i for i in range(n)})

# %%
nx.draw(G, pos=node_pos, edgelist=selected_edges, labels={i: i for i in range(n)})

# %%
shortest_edge: (5, 0), shortest_weight: 0.25713999924974384
shortest_edge: (0, 2), shortest_weight: 0.17080185272225637
shortest_edge: (2, 3), shortest_weight: 0.1893580701146991
shortest_edge: (3, 4), shortest_weight: 0.1364003883152551
shortest_edge: (2, 6), shortest_weight: 0.261617182211306
shortest_edge: (5, 1), shortest_weight: 0.2985981881435794
